# %% [markdown]
# # Домашнее задание по выборочным распределениям
# ## Азизов Мухаммад

# %%
import numpy as np
import pandas as pd
import random
from math import factorial
import scipy.stats as stats

# %% [markdown]
# #### 1.Производитель светодиодных лампочек заявляет что их продукция имеет средний срок службы в 2000 часов. Клиент считает что срок службы лампочек меньше заявляемого компанией. Чтобы проверить это клиент купил 50 лампочек производства этой компании и их средний срок службы составил 1980 часов, со стандартным отклонением в 66 часов. Проверьте гипотезы и вынесите заключение.

# %%
x_bar = 1980  
mu_0 = 2000   
s = 66        
n = 50        

t_stat = (x_bar - mu_0) / (s / np.sqrt(n))

p_value = stats.t.cdf(t_stat, df=n-1)

print(f"t-статистика: {t_stat:.4f}")
print(f"p-значение: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Отклоняем нулевую гипотезу: средний срок службы меньше 2000 часов.")
else:
    print("Не удалось отклонить нулевую гипотезу: недостаточно доказательств, что срок службы меньше 2000 часов.")
# Out:
# t-статистика: -2.1427
# p-значение: 0.0186
# Отклоняем нулевую гипотезу: средний срок службы меньше 2000 часов.

# %% [markdown]
# #### 2.Фасовочная машина заполняет мешки рисом в среднем по 1000гр на мешок и стандартным отклонением в 5гр. У производителя есть подозрение, что машина фасует рис в среднем больше требуемого. Он поручил сделать выборку из 100 мешков и их средний вес оказался равным 1003гр. Оправданы ли подозрения производителя?

# %%
x_bar = 1003
mu_0 = 1000
s = 5
n = 100

t_stat = (x_bar - mu_0) / (s / np.sqrt(n))
p_value = 1 - stats.t.cdf(t_stat, df=n-1)

print(f"t-статистика: {t_stat:.4f}")
print(f"p-значение: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Отклоняем нулевую гипотезу: машина фасует больше 1000 г.")
else:
    print("Не удалось отклонить нулевую гипотезу: недостаточно доказательств, что машина фасует больше 1000 г.")
# Out:
# t-статистика: 6.0000
# p-значение: 0.0000
# Отклоняем нулевую гипотезу: машина фасует больше 1000 г.

# %% [markdown]
# #### 3.Утверждается что домашние коты живут в среднем 15.7 лет. Учёный решил проверить истинность этого утверждения и замерил срок жизни 40 домашних котов в своём городе. Средний срок жизни котов в выборке оказался равным 16.5 годам со стандартным отклонением в 1.6 лет. Значит ли это, что коты в среднем живут дольше чем принято считать?

# %%
x_bar = 16.5
mu_0 = 15.7
s = 1.6
n = 40

t_stat = (x_bar - mu_0) / (s / np.sqrt(n))
p_value = 1 - stats.t.cdf(t_stat, df=n-1)

print(f"t-статистика: {t_stat:.4f}")
print(f"p-значение: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Отклоняем нулевую гипотезу: домашние коты живут дольше 15.7 лет.")
else:
    print("Не удалось отклонить нулевую гипотезу: недостаточно доказательств, что коты живут дольше 15.7 лет.")
# Out:
# t-статистика: 3.1623
# p-значение: 0.0015
# Отклоняем нулевую гипотезу: домашние коты живут дольше 15.7 лет.

# %% [markdown]
# #### 4.Здоровый новорожденный весит в среднем 3.40кг со стандартным отклонением в 0.45кг. Выборка из 49 новорожденных была взвешена и средний вес оказался равным 3.29кг. Проверьте следующие гипотезы: H_0: mu=3.40 и H_a: mu<3.4

# %%
x_bar = 3.29
mu_0 = 3.40
s = 0.45
n = 49

t_stat = (x_bar - mu_0) / (s / np.sqrt(n))
p_value = stats.t.cdf(t_stat, df=n-1)

print(f"t-статистика: {t_stat:.4f}")
print(f"p-значение: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Отклоняем нулевую гипотезу: средний вес новорожденных меньше 3.40 кг.")
else:
    print("Не удалось отклонить нулевую гипотезу: недостаточно доказательств, что средний вес меньше 3.40 кг.")
# Out:
# t-статистика: -1.7111
# p-значение: 0.0468
# Отклоняем нулевую гипотезу: средний вес новорожденных меньше 3.40 кг.

# %% [markdown]
# #### 5.В популяции средний показатель IQ составляет 100 со стандартным отклонением 15. Команда ученых хочет проверить новое лекарство, чтобы выяснить, оказывает ли оно положительное или отрицательное влияние на интеллект, или же не оказывает никакого эффекта. В выборке из 30 участников, которые принимали лекарство, средний показатель IQ составил 140. Повлияло ли лекарство на интеллект?

# %%
x_bar = 140
mu_0 = 100
s = 15
n = 30

t_stat = (x_bar - mu_0) / (s / np.sqrt(n))
p_value = 2 * (1 - stats.t.cdf(abs(t_stat), df=n-1))

print(f"t-статистика: {t_stat:.4f}")
print(f"p-значение: {p_value:.4f}")

alpha = 0.05
if p_value < alpha:
    print("Отклоняем нулевую гипотезу: лекарство повлияло на интеллект.")
else:
    print("Не удалось отклонить нулевую гипотезу: недостаточно доказательств, что лекарство повлияло на интеллект.")
# Out:
# t-статистика: 14.6059
# p-значение: 0.0000
# Отклоняем нулевую гипотезу: лекарство повлияло на интеллект.
